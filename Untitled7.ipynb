# %% [markdown]
# <a href="https://colab.research.google.com/github/RobertTalbert/discretecs/blob/master/Untitled7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import networkx as nx

# %%
3+4
# Out:
# 7

# %%
G = nx.Graph([(0, 1), (0, 2), (0, 3), (1, 2), (2, 6), (3, 4), (3, 5), (3, 6), (4, 5), (5, 6), (5, 7)])

# %%
nx.draw_circular(G, with_labels = True, node_color = "white")

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-5-48234beb69a7> in <module>
# ----> 1 nx.is_hamiltonian(G)
#
# /usr/local/lib/python3.7/dist-packages/networkx/__init__.py in __getattr__(name)
#      49             "This message will be removed in NetworkX 3.0."
#      50         )
# ---> 51     raise AttributeError(f"module {__name__} has no attribute {name}")
#      52
#      53
#
# AttributeError: module networkx has no attribute is_hamiltonian
