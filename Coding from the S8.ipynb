# %%
import networkx as nx

# %% [markdown]
# This is a markdown cell with some **math**: $x^2 + y^2 = z^2$

# %%
g = nx.gnp_random_graph(10, 0.4)
g.edges()
g.degree()
# Out:
# DegreeView({0: 4, 1: 3, 2: 3, 3: 2, 4: 6, 5: 2, 6: 4, 7: 2, 8: 2, 9: 2})

# %%
nx.draw_circular(g, with_labels= True, node_color = "lime")
