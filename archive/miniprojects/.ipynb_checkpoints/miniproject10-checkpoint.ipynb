# %% [markdown]
# # Miniproject 10: Clustering coefficients
#
# This is the second of three miniprojects exploring the __performance metrics__ of graphs that model social networks. Miniproject 9 focused on the _diameter_ of a network, which measures how "close-knit" or "dense" a network is. In this miniproject we explore the concept of __clustering coefficients__.
#
# ## Overview
#
# To motivate the idea of clustering coefficients, let's think about the people in some of your own social networks. In your networks, you will have some people who are the "social butterflies" of the network: Those people are in your network and tend to have others "clustered" around them who are also friends. At the same time, there are often people in your network who are your friends, but may not be friends with many other people.
#
# For example, look at this network:

# %%
network = Graph({'Ben': ['Gina', 'Mack'],
 'Jo': ['Carl', 'Dana', 'Ken', 'Fred'],
 'Abe': ['Carl', 'Dana', 'Gina', 'Fred'],
 'Carl': ['Jo', 'Abe', 'Dana'],
 'Dana': ['Jo', 'Abe', 'Carl', 'Eve', 'Ken', 'Mack'],
 'Eve': ['Dana', 'Mack'],
 'Gina': ['Ben', 'Abe'],
 'Hal': ['Mack'],
 'Ken': ['Jo', 'Dana'],
 'Mack': ['Ben', 'Dana', 'Eve', 'Hal', 'Bob'],
 'Fred': ['Jo', 'Abe'],
 'Bob': ['Mack']})
network.show()
# Out:
# Graphics object consisting of 30 graphics primitives

# %% [markdown]
# In this network, Dana and Carl have a special kind of role. They are connected to a lot of friends, and _those friends_ are connected to _each other_. It's like Carl and Dana are at the center of a [clique](http://www.merriam-webster.com/dictionary/clique) -- a small, close-knit group of friends who share connections not only with a common person but also to each other.
#
# Mack, on the other hand, is similarly connected to lots of friends -- but there's a difference: The friends that Mack is connected to, are not generally connected to each other. Mack is friends with Eve, Bob, Hal, Ben, and Dana but of those people, only Dana and Eve know each other. Mack is actually connected to more people than Carl is; but Carl's friends are more connected _to each other_ than Mack's friends are.
#
# The phenomenon that is happening with Carl and Dana, but which is not happening with Mack, is known in graph theory as __clustering__. We would say that Carl and Dana have "more clustering" than Mack does. Jo, too, has a high degree of clustering -- she is connected to four people and there is a lot of interconnections between her friends. In fact we might say that Jo and Carl have "the same amount of clustering".
#
# What we need here is a way to quantify the amount of clustering that a node in a graph has. That's the focus of this definition:
#
# >__Definition:__ Let $G$ be a graph and $v$ a node in the graph. Then the __clustering coefficient__ of $v$, denoted $CC(v)$, is given by the following formula:
# $$CC(v) = \left\{
# \begin{array}{cl}
# 0 & \text{if} \ \deg(v) = 0 \ \text{or} \ \deg(v) = 1 \\
# \dfrac{2 N_v}{K_v (K_v - 1)} & \text{if} \ \deg(v) \geq 2
# \end{array}
# \right.$$
# where $K_v = \deg(v)$ and $N_v$ is the number of edges between the _neighbors_ of $v$.
#
# _Note: This formula was modified from the version originally posted. See the Blackboard announcement on March 28 for details._
#
# So a node of degree 0 or 1 automatically has a clustering coefficient of 0; and for all other nodes, we use a formula. Let's break the formula down to understand its component parts and its output.
#
# Here is an example of graph in which a very small amount of clustering takes place:
#
# <img src="stargraph.png" height=300 width=300>
#
# Looking at node $v$, it is connected to several other nodes but there are _no_ connections between its neighbors. Then we can see that $K_v = \deg(v) = 6$ and $N_v$ -- the number of edges between the neighbors of $v$ -- is 0. Therefore in the formula, there would be a 0 in the numerator and so $CC(v) = 0$. This kind of graph is known as a _star graph_ for visual reasons.
#
# Now consider $K_6$, the complete graph on 6 nodes and pick any node you want within the graph and call it $v$. Then $K_v = \deg(v) = 5$, and the $N_v$ (again, the number of connections between the neighbors of $v$) is $C(5,2) = (5 \times 4)/2 = 10$. So the clustering coefficient of that node is
# $$CC(v) = \frac{2 N_v}{K_v (K_v - 1)} = \frac{2 \times 10}{5 \times 4} = 1$$
# The complete graph is the epitome of a clique, a small group that is highly interconnected.
#
# The star graph and $K_n$ are at opposite ends of a spectrum in terms of clustering. A star is as minimally clustered as possible; the complete graph is as highly clustered as possible. Therefore note that $CC(v)$ is a _fraction_ that can range from 0 to 1. A clustering coefficient of 0 indicates that the node is at the center of a star network; a clustering coefficient of 1 indicates the node resides within a clique. A clustering coefficient in between those extremes measures the "clique-ishness" of the node, that is, how interconnected its friends are.
#
# Back to the network above, let's compute some clustering coefficients.
#
# Start with Carl. His degree is 3. His neighbors are Jo, Dana, and Abe; there are two edges between those neighbors ({Jo, Dana} and {Dana, Abe}). Therefore for $v = \text{Carl}$, $K_v = 3$ and $N_v = 2$. So Carl's clustering coefficient is
# $$CC(v) = \frac{2 N_v}{K_v (K_v - 1)} = \frac{2 \cdot 2}{3 \cdot 2} = \frac{2}{3}$$
# Now look at Dana. His degree is 6. His neighbors are Abe, Carl, Jo, Ken, Eve and Mack; the number of edges between those neighbors is 4. So,
# $$CC(v) = \frac{2 N_v}{K_v (K_v - 1)} = \frac{2 \cdot 4}{6 \cdot 5} = \frac{4}{15}$$
# This is actually a lot less than Carl's clustering coefficient. Again, Dana is connected to _more people_, but those people are _less interconnected_ than the people to whom Carl is connected.
#
# Finally look at Mack. Mack's immediate neighbors _almost_ form a star, so we would expect his clustering coefficient to be close to 0. Let's check: His degree is 5; the number of edges between his neighbors is 1. Therefore his clustering coefficient is
# $$CC(v) = \frac{2 N_v}{K_v (K_v - 1)} = \frac{2 \cdot 1}{5 \cdot 4} = \frac{1}{10}$$
#
# The idea above of clustering coefficient is for _individual nodes_. But we can also define a _global_ idea of clustering that describes the tendency of an entire graph to have clustering:
#
# >__Definition:__ Let $G$ be a graph. Then the __clustering coefficient of the graph__ is denoted $CC(G)$ and is the average of the clustering coefficients of all the nodes in the graph.
#
# As an exercise to make sure you understand the idea of clustering coefficients, find the clustering coefficients of the remaining 9 nodes in the graph. (Some can be done in your head.) Then take the average of these to find the clustering coefficient of the entire graph; you should find it comes out to $53/180$ for the network above.
#
# In Sage, if `g` is a graph, then there are two methods that will determine clustering coefficients:
#
# + `g.clustering_coeff()` returns a dictionary whose keys are the nodes in the graph, and the value of each key is its clustering coefficient:

# %%
network.clustering_coeff()
# Out:
# {'Abe': 1/6,
#  'Ben': 0,
#  'Bob': 0,
#  'Carl': 2/3,
#  'Dana': 4/15,
#  'Eve': 1,
#  'Fred': 0,
#  'Gina': 0,
#  'Hal': 0,
#  'Jo': 1/3,
#  'Ken': 1,
#  'Mack': 1/10}

# %% [markdown]
# Are you surprised by the high clustering coefficient for Eve and Ken? Check back with the graph to see if you can explain. Also:
#
# + `g.clustering_average()` returns the clustering coefficient of the entire graph `g`:

# %%
network.clustering_average()
# Out:
# 53/180

# %% [markdown]
# Before you begin the tasks, you can also watch this four-minute video with more explanation and an example: https://www.youtube.com/watch?v=K2WF4pT5pFY
#
#
# ## Tasks for this Miniproject
#
# As with Miniproject 9, there are two options -- one that involves programming and one that doesn't. Please choose one.
#
# ### Option 1 (Programming)
#
# Do the following __in Python, not in Sage__. (Remember we use Python 3, not Python 2, for all "pure" Python tasks in MTH 325.)
#
# 1. Write a Python function called `clustering_coeff` that takes in two arguments: A social network/graph represented as a dictionary, and one of the nodes in the dictionary. The output of the function should be the clustering coefficient of the node.
# 2. Write a second Python function called `clustering_avg` that takes in one argument: A social network/graph represented as a dictionary. The output of the function is the clustering coefficient of the entire graph.
#
# Here is a screenshot with an example: https://goo.gl/vbTNOp  You can make lots more if you use Sage to practice.
#
# As with Miniproject 9, please note:
#
# You can generate many more sample values if you use Sage as described above. However, the function you write _must not use Sage_ but rather should be a "pure" Python function. _You may also not use any function from a Python library that will calculate the clustering coefficients directly._ The point of the miniproject is to write this procedure yourself. Functions that use any kind of pre-existing code that directly computes the clustering coefficient will be given a grade of "F".
#
# However, please note that _other Python libraries or functions that can help you write the code are OK._ You do not need to, nor are you expected to, write everything from scratch. If you can find a library or method or function that helps, use it. If you are in doubt as to whether a piece of pre-existing code is allowed, just ask me.
#
# Also please note the function should work on any dictionary that would define a legal graph in Sage. Remember that the graphs defined by `{0:[1], 1:[]}` and by `{0:[1], 1:[0]}` are the same, as we discussed in class.
#
# ### Option 2 (Non-programming)
#
# This option does not involve programming, but it does involve using Sage to create examples and to make observations and conjectures about your examples followed by a proof of those conjectures.
#
# 1. Using Sage, find the clustering coefficients of each of the nodes of the cycle graphs $C_2, C_3, C_4, \dots, C_{10}$. You can do more examples if you want. Based on your observations, make a conjecture about the clustering coefficients of nodes $C_n$ for any positive integer $n$. Then supply a clear and correct proof of your conjecture.
# 2. Using Sage, find the clustering coefficients of each of the nodes of the wheel graphs $W_2, W_3, W_4, \dots, W_{10}$. You can do more examples if you want. Based on your observations, make a conjecture about the clustering coefficientsof the nodes of $W_n$ for any positive integer $n$. Then supply a clear and correct proof of your conjecture.
# 3. Using Sage, find the clustering coefficients of each of the nodes of the cube graphs $Q_2, Q_3, Q_4, \dots, Q_{10}$. You can do more examples if you want. Based on your observations, make a conjecture about the clustering coefficients of the nodes of of $Q_n$ for any positive integer $n$. Then supply a clear and correct proof of your conjecture.
#
# ## Submission instructions
#
# A complete submission of this Miniproject consists of the following:
#
# + For both Options 1 and 2: At the top of the notebook, __clearly indicate which option you are submitting.__
# + For Option 1: A Jupyter notebook using the Python 3 kernel that contains all your code in a single Python 3 code block, along with a detailed explanation of how your function works. Please __do not include your examples in the main writeup__. These are to be done in a "scratch" notebook for your observations only. Please save the Jupyter notebook to your Dropbox folder and upload a PDF to Blackboard.
# + For Option 2: A Jupyter notebook wiht the SageMath kernel that contains Markdown cells with __clear statements of your three conjectures__ and clear, readable, and correct proofs of all three conjectures. Please upload a PDF copy of your notebook to Blackboard _and_ the raw Jupyter notebook as well just in case you have issues generating the PDF.
#
# The grading rubric for this miniproject depends on the Option.
#
# For Option 1:
#
# + E = The code works on all the test cases and the narrative section is clear and detailed.
# + M = The code works on most of the test cases, and the narrative section is clear and detailed.
# + R = The code does not work on most of the test cases; or the narrative section is not clear or detailed.
# + F = Something is missing or inadequately done: The narrative is not found, or the code throws syntax errors when evaluated, or the code uses Sage instead of pure Python, or something similar.
#
# For Option 2:
#
# + E = All three conjectures are correct and clearly stated, and the proofs are also clear, complete, and correct with only superficial errors.
# + M = There are minor but non-superficial errors in one or more of the conjectures or proofs, but for the most part the work is good.
# + R = There are significant errors in at least one of the conjectures or proofs.
# + F = One of the conjectures or proofs is missing or shows insufficient effort or a lack of partial understanding.
